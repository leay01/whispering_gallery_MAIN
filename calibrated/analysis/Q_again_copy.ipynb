# %%
import numpy as np
import pandas as pd 
import cmath 
import glob
import scipy.special as sp
import scipy.signal as spg
import scipy.constants as const
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 24
plt.rcParams['legend.fontsize'] = 8
import useful_functions as uf

# %%
# Q factor data sets: 

copper_coated_Al96_CTDim = uf.fix_csv('Qfac_eigensweep_0to10_CopperCoating_Al96_CTDim.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
CT_er9p7 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_CoorsTek_Er9.7.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
CT_newDim_CT9p8 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_CT9.8_newDim.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
just_er9p8 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_just_Er9.8.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
CT_properties_extensive = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_wCoorsTek_properties.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/') # probably still at 9.6? 

uf.find_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       6 just_er9p8 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_just_Er9.8.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
#       7 CT_properties_extensive = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_wCoorsTek_properties.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/') # probably still at 9.6?
# ----> 9 uf.find_
#
# AttributeError: module 'useful_functions' has no attribute 'find_'

# %%
copper_coated = uf.find_plot_Q_peaks(copper_coated_Al96_CTDim, n_peaks = 7)
copper_coated = uf.find_plot_Q_peaks(CT_er9p7, n_peaks = 7)
copper_coated = uf.find_plot_Q_peaks(CT_newDim_CT9p8, n_peaks = 7)
copper_coated = uf.find_plot_Q_peaks(just_er9p8, n_peaks = 7)
copper_coated = uf.find_plot_Q_peaks(CT_properties_extensive, n_peaks = 7)

# %%
Q_9p7 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_CoorsTek_Er9.7.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
Q_9p7_test = uf.find_plot_Q_peaks(Q_9p7, n_peaks = 5)

# %%
copper_coated = uf.find_plot_Q_peaks_chunk(copper_coated_Al96_CTDim, n_peaks = 7, f_start=2.8, f_stop=3.4)
copper_coated = uf.find_plot_Q_peaks_chunk(CT_er9p7, n_peaks = 7, f_start=2.8, f_stop=3.4)
copper_coated = uf.find_plot_Q_peaks_chunk(CT_newDim_CT9p8, n_peaks = 7, f_start=2.8, f_stop=3.4)
copper_coated = uf.find_plot_Q_peaks_chunk(just_er9p8, n_peaks = 7, f_start=2.8, f_stop=3.4)
copper_coated = uf.find_plot_Q_peaks_chunk(CT_properties_extensive, n_peaks = 7, f_start=2.8, f_stop=3.4)

# %%
Q_9p8 = uf.fix_csv('Qfac_eigensweep_500MHz_to_10GHz_just_Er9.8.csv', '/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_data/')
Q_9p8_test = uf.find_plot_Q_peaks(Q_9p8, n_peaks = 5)
