# %%
import VNA_data_read_ as vdr
import matplotlib.pyplot as plt

# %%
test = vdr.loader_plotter('BL_1601_PWR-10to101_2025-05-16_13-10-41.txt', 'disk_1601_PWR-10to101_2025-05-16_13-12-35.txt', 'data/broadband_051624')

# %%
BL_closer, disk_closer = vdr.loader_plotter('BL_1601_PWR-15to5_closer2_2025-05-16_13-39-01.txt', 'disk_1601_PWR-15to5_closer2_2025-05-16_13-36-23.txt', 'data')

# %%
BL_0to5, DR_0to5 = vdr.loader_plotter('BL_0to5GHz_1601_PWR-15to5_closer3_2025-05-16_13-43-37.txt', 'disk_0to5GHz_1601_PWR-15to5_closer3_2025-05-16_13-45-34.txt', 'data')

# %%
BL5to10, disk5to10 = vdr.loader_plotter('BL_5to10GHz_1601_PWR-15to5_closer3_2025-05-16_13-52-12.txt', 'disk_5to10GHz_1601_PWR-15to5_closer3_2025-05-16_13-50-42.txt', 'data')
plt.savefig('first')

# %%
narrow_0_2 = vdr.loader_plotter('BL_Narrow_5MHz_to_2GHz_-15to5dB_1601_2025-05-16_15-38-15.txt', 'DISK_Narrow_0.08GHz_to_2GHz_-15to5dB_1601_2025-05-16_15-53-37.txt', 'data/narrow_2GHz_step')

# %%
narrow_6_8 = vdr.loader_plotter('BL_Narrow_6GHz_to_8GHz_-15to5dB_1601_2025-05-16_15-44-02.txt', 'DISK_Narrow_6GHz_to_8.08GHz_-15to5dB_1601_2025-05-16_15-58-42.txt', 'data/narrow_2GHz_step')
