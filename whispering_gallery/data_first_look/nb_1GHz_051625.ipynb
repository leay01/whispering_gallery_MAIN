# %%
import VNA_data_read_local as vdr
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data_first_look'

# %%
BL9to10, DISK9to10 = vdr.loader_plotter('BL_Narrow_9.08to9.88GHz_-15to5dB_1601_2025-05-16_16-35-32.txt', 'DISK_Narrow_9.08to9.88GHz_-15to5dB_1601_2025-05-16_16-20-13.txt', 'data')
