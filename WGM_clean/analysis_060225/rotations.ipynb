# %%
import numpy as np
import pandas as pd 
import cmath 
import glob
import scipy.special as sp
import scipy.signal as spg
import scipy.constants as const
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 24
#plt.rcParams['legend.fontsize'] = 10
import VNA_data_read_local as vdr


import sys
sys.path.append('/Users/leayamashiro/whispering_gallery_MAIN/wgm_code/Q_fac_analysis/')
import useful_functions as uf


# loading file folder
rot_060225 = glob.glob('/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/*.txt')

# %%
rot_060225
# Out:
# ['/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot4_2.4to5.6GHz_2025-06-02_17-37-40.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot5_2.4to5.6GHz_2025-06-02_17-43-32.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot6_2.4to5.6GHz_2025-06-02_17-46-38.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot6_2.4to5.6GHz_2025-06-02_17-49-27.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot1_2.4to5.6GHz_2025-06-02_17-23-08.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot8_2.4to5.6GHz_2025-06-02_17-56-22.txt',
#  '/Users/leayamashiro/whispering_gallery_MAIN/whispering_gallery/data/rotation_data_060225/rot1_FLIPPED_2.4to5.6GHz_2025-06-02_18-15-47.txt',
# ...

# %%
baseline, rot1 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot1_2.4to5.6GHz_2025-06-02_17-23-08.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 1')

baseline, rot2 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot2_2.4to5.6GHz_2025-06-02_17-28-27.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 2')


baseline, rot3 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot3_2.4to5.6GHz_2025-06-02_17-34-01.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 3')


baseline, rot4 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot4_2.4to5.6GHz_2025-06-02_17-37-40.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 4')


baseline, rot5 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot5_2.4to5.6GHz_2025-06-02_17-43-32.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 5')


baseline, rot6 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot6_2.4to5.6GHz_2025-06-02_17-49-27.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 6')


baseline, rot7 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot7_2.4to5.6GHz_2025-06-02_17-53-42.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 7')


baseline, rot8 = vdr.loader_plotter('baseline1_2.4to5.6GHz_2025-06-02_17-58-08.txt', 
                                    'rot8_2.4to5.6GHz_2025-06-02_17-56-22.txt', 
                                    'data/rotation_data_060225', title = 'Rotation 8')

# %%
rot1_w_dips = uf.find_plot_dips(baseline, rot1, f_start)
