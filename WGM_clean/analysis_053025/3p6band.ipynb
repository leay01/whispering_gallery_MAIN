# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import VNA_data_read_local as vdr

# %% [markdown]
# ### High-Quality Band (HQB), from 2.94 GHz to 4.06 GHz.

# %%
HQB_freqs, HQB_baseline1, HQB_disk1, HQB_bl_sub1 = vdr.load_subtract_getfreqs('HQB_2.94to4.06GHz_baseline1_2025-05-30_13-17-25.txt', 
                                                                          'HQB_2.94to4.06GHz_0.5mm_disk1_2025-05-30_13-23-12.txt', 
                                                                          'data_053025')

HQB_gp5_freqs, HQB_gp5_baseline1, HQB_gp5_disk1, HQB_gp5_bl_sub1 = vdr.load_subtract_getfreqs('HQB_2.94to4.06GHz_baseline3_2025-05-30_13-19-12.txt', 
                                                                                              'HQB_2.94to4.06GHz_over0.5_disk2_2025-05-30_13-48-37.txt', 
                                                                                              'data_053025')

# %%
#plt.plot(HQB_freqs, HQB_baseline1, label = 'baseline')
plt.plot(HQB_freqs, HQB_bl_sub1, label = 'baseline subtracted')

# %%
plt.plot(HQB_gp5_freqs, HQB_gp5_bl_sub1)

# %%
HQB_gp5_BL, HQB_gp5_res = vdr.loader_plotter('HQB_2.94to4.06GHz_baseline3_2025-05-30_13-19-12.txt', 
                                            'HQB_2.94to4.06GHz_over0.5_disk2_2025-05-30_13-48-37.txt', 
                                            'data_053025')
